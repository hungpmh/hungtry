# %%
import scipy.stats
scipy.stats.t(20).cdf(1.96)
#scipy.stats.norm(0, 1).pdf(0)
# Out:
# 0.9679608734982115

# %%
import scipy.stats #nạp vào thư viện thống kê
scipy.stats.norm(0,1).cdf(0) # cho ta giá trị của hàm phân bố chuẩn với kì vọng bằng 0, phương sai bằng 1 tại x=0= P(X<0)
#vơi X là biến ngẫu nhiênphân bố chuẩn với kì vọng bằng 0, phương sai bằng 1
# Out:
# 0.5

# %%
scipy.stats.norm(0,1).cdf(1.96)# cho ta giá trị của hàm phân bố chuẩn với kì vọng bằng 0, phương sai bằng 1 tại x=1.96 giá trị này bằng  P(X<1.96)
#vơi X là biến ngẫu nhiênphân bố chuẩn với kì vọng bằng 0, phương sai bằng 1
# Out:
# 0.9750021048517795

# %%
scipy.stats.norm(0, 1).pdf(0)# Giá trị của hàm mật độ tại x=0 của phân bố chuẩn kì vọng 0 phương sai=1
# Out:
# 0.3989422804014327

# %%
scipy.stats.norm(0, 1).pdf(2)# Giá trị của hàm mật độ tại x=2 của phân bố chuẩn kì vọng 0 phương sai=1
# Out:
# 0.05399096651318806

# %%
scipy.stats.norm(0, 1).pdf(3)# Giá trị của hàm mật độ tại x=3 của phân bố chuẩn kì vọng 0 phương sai=1
# Out:
# 0.0044318484119380075

# %%
scipy.stats.norm(0, 1).pdf(-0.5)#Giá trị của hàm mật độ tại x=-0.5 của phân bố chuẩn kì vọng 0 phương sai=1
# Out:
# 0.3520653267642995

# %%
# Giá trị của phân bố chuẩn như trên tập trung lớn xung quanh giá trị 0

# %%
P(X<1.96)=0.975

# %%
scipy.stats.t(20).cdf(0)# Giá trị của hàm phân bố Student với 20 bậc tự do tại t=0 là P(T<0)
# Out:
# 0.5

# %%
scipy.stats.t(20).cdf(1.96)# Giá trị của hàm phân bố Student với 20 bậc tự do tại t=1.96 là P(T<1.96)
# Out:
# 0.9679608734982115

# %%
scipy.stats.t(30).cdf(1.96)# Giá trị của hàm phân bố Student với 30 bậc tự do tại t=1.96 là P(T<1.96)
# Out:
# 0.9703288435519748

# %%
scipy.stats.t(50000).cdf(1.96)# Giá trị của hàm phân bố Student với 50000 bậc tự do tại t=1.96 là P(T<1.96)
# Out:
# 0.9749993319432845

# %%
scipy.stats.chi2(30).cdf(30.96)# Giá trị của hàm phân bố Khi-bình phương với 30 bậc tự do tại t=30.96 là P(T<30.96)
# Out:
# 0.5826244614980767

# %%
scipy.stats.f(4,5).cdf(5.96)# Giá trị của hàm phân bố Fisher với 4 và 5 bậc tự do tại t=5.96 là P(T<5.96)
# Out:
# 0.9616212921553792

# %%
scipy.stats.binom(12,0.65).cdf(5)# Giá trị của hàm phân bố nhị thức tích lũy với n=12 và p=0.65 bậc tự do tại k=5 là P(X<=5)
# Out:
# 0.08463206512156687

# %%
scipy.stats.binom(12,0.65).cdf(4)
# Out:
# 0.025507456998908686

# %%
scipy.stats.binom(12,0.65).cdf(3)
# Out:
# 0.005609752342244872

# %%
scipy.stats.binom(12,0.65).cdf(2)
# Out:
# 0.0008479084927868648

# %%
scipy.stats.binom(12,0.65).cdf(1)
# Out:
# 7.868756325903315e-05

# %%
scipy.stats.binom(12,0.65).cdf(5)-scipy.stats.binom(12,0.65).cdf(4)#P(X=5)=P(X<=5)-P(X<=4)
# Out:
# 0.059124608122658184

# %%
scipy.stats.expon(12).cdf(5)# Phân bố mũ
# Out:
# 0.0

# %%
scipy.stats.poisson(12).cdf(5) # Phân bố Poison
# Out:
# 0.020341029416928398

# %%
1-scipy.stats.norm(78.5,11.2).cdf(80)
# Out:
# 0.44672952853888204

# %%
1-scipy.stats.norm(78.5,11.2/5).cdf(80)
# Out:
# 0.2515427434057965

# %%
import numpy as np
1-scipy.stats.norm(78.5,11.2/np.sqrt(20)).cdf(80)
# Out:
# 0.27460418752004845

# %%
1-scipy.stats.norm(78.5,11.2).cdf(80)
# Out:
# 0.44672952853888204

# %%
import numpy as np
1-scipy.stats.norm(0,1).cdf((80-78.5)/(11.2/np.sqrt(20)))
# Out:
# 0.27460418752004845

# %%
import scipy.stats
scipy.stats.binom(20,0.5).cdf(10)
#scipy.stats.norm(0, 1).pdf(0)
# Out:
# 0.5880985260009768

# %%
import scipy.stats
scipy.stats.binom(20,0.5).cdf(10)
#scipy.stats.norm(0, 1).pdf(0)

# %%
import scipy.stats
scipy.stats.chi2(20,0.5).cdf(10)
#scipy.stats.norm(0, 1).pdf(0)
# Out:
# 0.02364069482096414

# %%
import scipy.stats
scipy.stats.f(20,1,0.5).cdf(10)
#scipy.stats.norm(0, 1).pdf(0)
# Out:
# 0.7489716627079761

# %%
import scipy.stats
scipy.stats.expon(2).cdf(5)
#scipy.stats.norm(0, 1).pdf(0)
# Out:
# 0.950212931632136

# %%
import scipy.stats
scipy.stats.poisson(2).cdf(10)
#scipy.stats.norm(0, 1).pdf(0)
# Out:
# 0.9999916917756315

# %%
import scipy.stats as stats
import math

def one_sample_ztest_pop_proportion(tail, p, pbar, n, alpha):
    #Calculate test stat

    sigma = math.sqrt((p*(1-p))/(n))
    z = round((pbar - p) / sigma, 2)

    if tail == 'lower':
        pval = round(stats.norm(p, sigma).cdf(pbar),4)
        print("Results for a lower tailed z-test: ")


    elif tail == 'upper':
        pval = round(1 - stats.norm(p, sigma).cdf(pbar),4)
        print("Results for an upper tailed z-test: ")


    elif tail == 'two':
        pval = round(stats.norm(p, sigma).cdf(pbar)*2,4)
        print("Results for a two tailed z-test: ")


    #Print test results
    print("Test statistic = {}".format(z))   
    print("P-value = {}".format(pval))
    print("Confidence = {}".format(alpha))

    #Compare p-value to confidence level
    if pval <= alpha:
        print("{} <=  {}. Reject the null hypothesis.".format(pval, alpha))
    else:
        print("{} > {}. Do not reject the null hypothesis.".format(pval, alpha))


#one_sample_ztest_pop_proportion('upper', .20, .25, 400, .05)

#one_sample_ztest_pop_proportion('two', .64, .52, 100, .05
