# %%
import pandas as pd
Thinh = pd.read_csv('2008_swing_states.csv')
Thinh.head(5)
# Out:
#   state           county  total_votes  dem_votes  rep_votes  dem_share
# 0    PA      Erie County       127691      75775      50351      60.08
# 1    PA  Bradford County        25787      10306      15057      40.64
# 2    PA     Tioga County        17984       6390      11326      36.07
# 3    PA    McKean County        15947       6465       9224      41.21
# 4    PA    Potter County         7507       2300       5109      31.04

# %%
Thinh['county']
# Out:
# 0          Erie County
# 1      Bradford County
# 2         Tioga County
# 3        McKean County
# 4        Potter County
#             ...
# 217    Hamilton County
# 218    Highland County
# 219     Hocking County
# 220     Licking County
# 221     Madison County
# Name: county, Length: 222, dtype: object

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
_ = plt.hist(Thinh['dem_share']) # Vẽ biểu đồ dạng histogram cho cột dem_share: tỉ lệ vote cho đảng dân chủ (Obama)
_ = plt.xlabel('Tỉ lệ bầu cho Obama')#Tiêu đề trên trục hoành
_ = plt.ylabel('Số lượng các hạt')
plt.show()

# %%
_ = plt.hist(Thinh['dem_share'], bins=40)

# %%
import seaborn as sns # gọi thư viện seaborn
sns.set() #Thiết lập môi trường seabo
_ = plt.hist(Thinh['dem_share'])
_ = plt.xlabel('percent of vote for Obama')
_ = plt.ylabel('number of counties')
plt.show()

# %%
In [1]: _ = sns.swarmplot(x='state', y='dem_share', data=Thinh)
In [2]: _ = plt.xlabel('state')
In [3]: _ = plt.ylabel('percent of vote for Obama')
In [4]: plt.show()

# %%
data = pd.read_csv('/content/2008_all_states.csv')
data.head()
# Out:
#   state                                       county  ...  dem_share  east_west
# 0    AK    State House District 8, Denali-University  ...      50.06       west
# 1    AK  State House District 37, Bristol Bay-Aleuti  ...      41.24       west
# 2    AK  State House District 12, Richardson-Glenn H  ...      25.93       west
# 3    AK      State House District 13, Greater Palmer  ...      24.93       west
# 4    AK     State House District 14, Greater Wasilla  ...      20.82       west
#
# [5 rows x 8 columns]

# %%
plt.figure(figsize=(14,6))
_ = sns.swarmplot(x='east_west', y='dem_votes', data=data) # Vẽ cho từng bang, mỗi giá trị của dem_share trong mỗi hạt của từng bang
# được xếp thành từng điểm không trùng nhau. Nếu 2 giá trị bằng nhau thì được xếp cạnh nhau và song song với nhau: cùng hàng ngang
_ = plt.xlabel('east_west')
_ = plt.ylabel('percent of vote for Obama')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-96c799b46cb8> in <module>()
#       1 plt.figure(figsize=(14,6))
# ----> 2 _ = sns.swarmplot(x='east_west', y='dem_votes', data=data) # Vẽ cho từng bang, mỗi giá trị của dem_share trong mỗi hạt của từng bang
#       3 # được xếp thành từng điểm không trùng nhau. Nếu 2 giá trị bằng nhau thì được xếp cạnh nhau và song song với nhau: cùng hàng ngang
#       4 _ = plt.xlabel('east_west')
#       5 _ = plt.ylabel('percent of vote for Obama')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
import numpy as np # Gọi thư viện numpy bao gồm các tính toán số học và đại số
x = np.sort(Thinh['dem_share'])
y = np.arange(1, len(x)+1) / len(x)
_ = plt.plot(x, y, marker='.', linestyle='none')
_ = plt.xlabel('Tỉ lệ phần trăm phiếu bầu cho Obama')
_ = plt.ylabel('Xác suất tương ứng-')
plt.margins(0.02) # Keeps data off plot edges
plt.show()
