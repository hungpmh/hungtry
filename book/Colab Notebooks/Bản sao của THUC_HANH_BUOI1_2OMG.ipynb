# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import math # thư viện tính toán
import matplotlib.pyplot as plt # thư viện vẽ
# %matplotlib inline
import seaborn as sns # thư viện vẽ
print('setup complete')
plt.style.use('seaborn-darkgrid')
palette=plt.get_cmap('Set2')
# Out:
# setup complete

# %%
data=pd.read_csv('/content/telecom_users.csv')
data
# Out:
#       Unnamed: 0  customerID  gender  ...  MonthlyCharges TotalCharges Churn
# 0           1869  7010-BRBUU    Male  ...           24.10      1734.65    No
# 1           4528  9688-YGXVR  Female  ...           88.15       3973.2    No
# 2           6344  9286-DOJGF  Female  ...           74.95      2869.85   Yes
# 3           6739  6994-KERXL    Male  ...           55.90        238.5    No
# 4            432  2181-UAESM    Male  ...           53.45        119.5    No
# ...          ...         ...     ...  ...             ...          ...   ...
# 5981        3772  0684-AOSIH    Male  ...           95.00           95   Yes
# 5982        5191  5982-PSMKW  Female  ...           91.10       2198.3    No
# 5983        5226  8044-BGWPI    Male  ...           21.15       306.05    No
# 5984        5390  7450-NWRTR    Male  ...           99.45      1200.15   Yes
# 5985         860  4795-UXVCJ    Male  ...           19.80        457.3    No
#
# [5986 rows x 22 columns]

# %%
data.nunique()
# Out:
# Unnamed: 0          5986
# customerID          5986
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1526
# TotalCharges        5611
# Churn                  2
# dtype: int64

# %%
data.Contract.unique()
# Out:
# array(['Two year', 'Month-to-month', 'One year'], dtype=object)

# %%
data.StreamingMovies.unique()
# Out:
# array(['No internet service', 'No', 'Yes'], dtype=object)

# %%
x=data.MonthlyCharges
x.describe()

# %%
import numpy as np
x = np.sort(data.MonthlyCharges)
y = np.arange(1, len(x)+1) / len(x)
_ = plt.plot(x, y, marker='.', linestyle='none')
_ = plt.xlabel('Phí hàng tháng')
_ = plt.ylabel('Hàm phân phối thực nghiệm')
#plt.margins(0.02) # Keeps data off plot edges
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 7889 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 7921 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 7879 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 7889 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 7921 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
data['StreamingMovies'].unique()

# %%
data.dtypes
# Out:
# Unnamed: 0            int64
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
np.mean(data.tenure)
# Out:
# 32.46876044102907

# %%
np.median(data.tenure)
# Out:
# 29.0

# %%
# Hàm phân bố thực nghiệm 
x = np.sort(data.tenure)
y = np.arange(1, len(x)+1) / len(x)
_ = plt.plot(x, y, marker='.', linestyle='none')
_ = plt.xlabel('Số tháng sử dụng dịch vụ viễn thông')
_ = plt.ylabel('Hàm phân bố thực nghiệm')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
_ = sns.boxplot(x='gender', y='tenure',data=data)
_ = plt.xlabel('Giới tính')
_ = plt.ylabel('Số tháng sử dụng dịch viễn thông')
plt.show()

# %%
np.percentile(data['tenure'], [25, 50, 75])
# Out:
# array([ 9., 29., 56.])

# %%
# 25% khách hàng sử dụng dịch vụ dưới 9 tháng
# 50% khách hàng sử dụng dịch vụ dưới 29 tháng
# 75% khách hàng sử dụng dịch vụ dưới 56 tháng

# %%
Phân bố về sử dụng dịch vụ của nam và nữ khá tương đồng

# %%
np.mean(data.MonthlyCharges)
# Out:
# 64.8022134981624

# %%
np.median(data.MonthlyCharges)
# Out:
# 70.4

# %%
np.mode(data.MonthlyCharges)

# %%
x = np.sort(data.MonthlyCharges)
y = np.arange(1, len(x)+1) / len(x)
_ = plt.plot(x, y, marker='.', linestyle='none')
_ = plt.xlabel('Chi phí hàng tháng cho dịch vụ viễn thông')
_ = plt.ylabel('Hàm phân bố thực nghiệm')

# %%
np.percentile(data['MonthlyCharges'], [25, 50, 75])
# Out:
# array([35.65, 70.4 , 89.9 ])

# %%
# Có 25% số khách hàng chi trả hàng tháng dưới 35.65 USD cho dịch vụ viễn thông
# Có 50% số khách hàng chi trả hàng tháng dưới 70.4 USD cho dịch vụ viễn thông
# Có 75% số khách hàng chi trả hàng tháng dưới 89.9 USD cho dịch vụ viễn thông

# %%
np.percentile(data['MonthlyCharges'], [45, 60, 90])
# Out:
# array([ 65.5  ,  79.15 , 102.825])

# %%
def dot(x,y):
 
  return sum(x_i * y_i
 
       for x_i, y_i in zip(x, y))
 
# hiệp phương sai
 
def covariance(x, y):
 
  n = len(x)
 
  return dot(deviation(x), deviation(y)) / (n - 1)
 
# tính hệ số tương quan
 
def correlation(x, y):
 
   stdev_x = standard_deviation(x)
 
   stdev_y = standard_deviation(y)
 
   if stdev_x > 0 and stdev_y > 0:
 
      return covariance(x, y) / (stdev_x * stdev_y)
 
   else:
 
      return 0

# %%
plt.scatter(data['tenure'],data['MonthlyCharges'])
 
plt.show()

# %%
np.cov(data['tenure'],data['MonthlyCharges'])
# Out:
# array([[601.05340989, 189.7317776 ],
#        [189.7317776 , 906.8952545 ]])

# %%
np.corrcoef(data['tenure'],data['MonthlyCharges'])
# Out:
# array([[1.        , 0.25698335],
#        [0.25698335, 1.        ]])

# %%
# hệ số tương quan giữa số tháng sử dụng và chi phí hàng tháng không lớn cỡ khoảng 0.256 
#do vậy việc khách hàng bỏ dịch vụ không phụ thuộc nhiều vào chi phí hàng tháng

# %%
# 45% số khách hàng chi trả dưới 65.5 USD một tháng

# %%
data.describe(include=[np.number])
# Out:
#         Unnamed: 0  SeniorCitizen       tenure  MonthlyCharges
# count  5986.000000    5986.000000  5986.000000     5986.000000
# mean   3533.561310       0.161377    32.468760       64.802213
# std    2035.705666       0.367909    24.516391       30.114702
# min       0.000000       0.000000     0.000000       18.250000
# 25%    1777.250000       0.000000     9.000000       35.650000
# 50%    3546.500000       0.000000    29.000000       70.400000
# 75%    5291.750000       0.000000    56.000000       89.900000
# max    7042.000000       1.000000    72.000000      118.750000

# %%
x.describe

# %%
 import numpy as np
np.mean(x)
# Out:
# 64.80221349816237

# %%
import matplotlib.pyplot as plt
_ = plt.hist(data['MonthlyCharges'])
_ = plt.xlabel('MonthlyCharges')
_ = plt.ylabel('Tần số')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 7847 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 7889 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 7847 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 7889 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
In [1]: import seaborn as sns
In [2]: sns.set()
In [3]: _ = plt.hist(data['MonthlyCharges'])
In [4]: _ = plt.xlabel('MonthlyCharges')
In [5]: _ = plt.ylabel('Tần số')
In [6]: plt.show()

# %%
data.InternetService.unique()
# Out:
# array(['No', 'Fiber optic', 'DSL'], dtype=object)

# %%
data.describe(include=[np.object])
# Out:
#         customerID gender Partner  ...     PaymentMethod TotalCharges Churn
# count         5986   5986    5986  ...              5986         5986  5986
# unique        5986      2       2  ...                 4         5611     2
# top     8464-EETCQ   Male      No  ...  Electronic check                 No
# freq             1   3050    3082  ...              2006           10  4399
#
# [4 rows x 18 columns]

# %%
# Conclusions that can be drawn at the moment:
# + The difference between the sexes of clients is very small - about 50 people (male gender prevails).
# + Most clients have no dependents.
# + 90% of clients have a telephone service connected.
# + On average, half of the clients do not use additional services.
# + Half of the clients have a contract type - "From month to month".
# + More than half of customers use paperless billing.
# + One third of clients have a payment method - "Electronic check".

# %%
gender=data['gender'].value_counts() # Đồ thị dạng pie so sánh số lượng khách hàng là nam hay nữ
plt.figure(figsize=(10,5))
plot=gender.plot.pie(fontsize=20,autopct='%1.02f%%',labeldistance=1.2,radius=1.5)# autopct ;à định số viết trên biểu đồ, radius là bán kính của biểu đồ, fontsize là kích cỡ của tiêu đề

# %%
gender=data['gender'].value_counts()
plt.figure(figsize=(7,5))
plot=gender.plot.pie(autopct='%1.02f%%',labeldistance=1.3,radius=2)

# %%
SeniorCitizen=data['SeniorCitizen'].value_counts()
plt.figure(figsize=(7,5))
plot=SeniorCitizen.plot.pie(fontsize=16,autopct='%1.02f%%',labeldistance=1.2,radius=2)

# %%
# có đến 86% khách hàng không phải là seniorCitizen

# %%
PaymentMethod=data['PaymentMethod'].value_counts()
plt.figure(figsize=(7,5))
explode=(0.1,0.2,0.5,0)
plot=PaymentMethod.plot.pie(fontsize=16,autopct='%1.01f%%',labeldistance=1.2,radius=2,explode=explode)
# tham số explode=(0.1,0.2,0.5,0) cho phép đồ thị tao ra những khoảng trống giữa các phần với nhau.
# Các tham số trong explode cho khoảng giãn cách giưã các phần đồ thị

# %%
StreamingMovies=data['StreamingMovies'].value_counts()
plt.figure(figsize=(7,5))
explode=(0.1,0,0)
plot=StreamingMovies.plot.pie(fontsize=16,autopct='%1.02f%%',labeldistance=1.2,radius=2,explode=explode)

# %%
Partner=data['Partner'].value_counts()
plt.figure(figsize=(7,5))
explode=(0.1,0)
plot=Partner.plot.pie(fontsize=16,autopct='%1.02f%%',labeldistance=1.2,radius=2,explode=explode)

# %%
ismaried=data['Partner'].value_counts()
plt.figure(figsize=(7,5))
sns.barplot(x=ismaried.index,y=ismaried.values,alpha=0.8)
plt.title('Number of client is maried or not',fontsize=18,pad=10)
plt.ylabel('Number of client',fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Out:
# (array([   0.,  500., 1000., 1500., 2000., 2500., 3000., 3500.]),
#  <a list of 8 Text major ticklabel objects>)

# %%
# Số lượng khách hàng chưa kết hôn nhiều hơn so với đã kết hôn

# %%
sns.barplot(x='Partner',y='MonthlyCharges',data=data)

# %%
sns.barplot(x='Dependents',y='MonthlyCharges',data=data)

# %%
# Những người không phụ thuộc sẽ chi trả hàng tháng nhiều tiền hơn

# %%
sns.barplot(x='SeniorCitizen',y='MonthlyCharges',data=data)
plt.xlabel('So sánh chi tiêu của công dân cao cấp và thường dân')
# Out:
# Text(0.5, 0, 'So sánh chi tiêu của công dân cao cấp và thường dân')

# %%
# Công dân thượng lưu sẽ chi trả hàng nhiều hơn cho các dịch vụ viễn thông

# %%
 #Trong 1-2 tháng ~ 510 người sử dụng dịch vụ, nhưng sau đó nó giảm mạnh. 

tenure = data['tenure']

plt.figure(figsize=(10, 7))
sns.histplot(tenure, bins=50, alpha=0.5)

plt.title('How many months a person has been a client of the company', fontsize=18, pad=10)
plt.xticks(list(range(0, tenure.max(), 2)), fontsize=12)
plt.yticks(list(range(0, 550, 30)), fontsize=12)
plt.xlabel('Number of months', fontsize=16)
plt.ylabel('Number of client',fontsize=14)
# Out:
# Text(0, 0.5, 'Number of client')

# %%
tenure.describe() # Thời gian sử dụng dịch vụ
# Out:
# count    5986.000000
# mean       32.468760
# std        24.516391
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        56.000000
# max        72.000000
# Name: tenure, dtype: float64

# %%
tenure.mode()
# Out:
# 0    1
# dtype: int64

# %%
phone_servise = data['PhoneService'].value_counts()

plt.figure(figsize=(10, 7))

sns.barplot(x=phone_servise.index, y=phone_servise.values, alpha=0.8)
plt.title('Số lượng khách hàng sử dụng telephone', fontsize=18, pad=10)
plt.ylabel('Number of clients', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=10)
plt.show()

# %%
InternetService = data['InternetService'].value_counts()

plt.figure(figsize=(10, 7))

sns.barplot(x=InternetService.index, y=InternetService.values, alpha=0.8)
plt.title('NSố lượng khách hàng sử dụng dịch vụ internet', fontsize=18, pad=10)
plt.ylabel('Number of clients', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=10)
plt.show()

# %%
data['InternetService'].unique()
# Out:
# array(['No', 'Fiber optic', 'DSL'], dtype=object)

# %%
# Trung bình, một nửa số khách hàng không sử dụng các dịch vụ bổ sung. Khoảng 2/3 khách hàng sử dụng các dịch vụ bổ sung
other_servises = ['MultipleLines', 'InternetService', 'OnlineSecurity',
                  'OnlineBackup', 'DeviceProtection', 'TechSupport',
                  'StreamingTV', 'StreamingMovies']

fig, ax = plt.subplots(nrows=4, ncols=2, figsize=(20, 15), sharey=True)
t = 0


for i in range(4):
    for j in range(2):
        data_prep = [data[obj].value_counts()  for obj in other_servises]
        axes = ax[i][j]

        sns.barplot(x=data_prep[t].index, y=data_prep[t].values, ax=axes, alpha=0.8)
        axes.set_title(other_servises[t], fontsize=16)
        axes.set_yticks(list(range(0, 3001, 500)))
        if j == 0:
            axes.set_ylabel('Number of clients', fontsize=12)
        t += 1

fig.suptitle('Customers who use additional services', y=0.93, fontsize=20)
plt.show()

# %%
# khoảng một nửa số khách hàng có loại hợp đồng "Từ tháng này sang tháng khác" và khoảng 1/4 mỗi khách hàng có loại hợp đồng "Hai năm" và "Một năm".
contract = data['Contract'].value_counts()

plt.figure(figsize=(10, 7))

sns.barplot(x=contract.index, y=contract.values, alpha=0.8)
plt.title('Number of clients and their type of contract', fontsize=18, pad=10)
plt.ylabel('Number of clients', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=10)
plt.show()

# %%
PaymentMethod = data['PaymentMethod'].value_counts()

plt.figure(figsize=(15, 7))

sns.barplot(x=PaymentMethod.index, y=PaymentMethod.values, alpha=0.8)
plt.title('Number of clients and their type of PaymentMethod', fontsize=18, pad=10)
plt.ylabel('Number of clients', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=10)
plt.show()

# %%
montly_charges = data['MonthlyCharges']

plt.figure(figsize=(10, 7))

sns.distplot(montly_charges).set(ylabel='Tỉ lệ', xlabel='Payment amount')
plt.title('Monthly payment to date', fontsize=18)
plt.xlabel('Payment amount', fontsize=14)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
