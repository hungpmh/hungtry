# %%
import pandas as pd

# %%
df=pd.DataFrame({'Bob':['i liked it','im alone'],
                 'Nam':['you are a boy','did they sleep?'],
                 'Khánh':['1','2']},
                index=['1','2'])
df
# Out:
#           Bob              Nam Khánh
# 1  i liked it    you are a boy     1
# 2    im alone  did they sleep?     2

# %%
test=pd.Series([1,2,3,4,5],index=['Meo','Cho','lon','Ga','Bo'])
test
# Out:
# Meo    1
# Cho    2
# lon    3
# Ga     4
# Bo     5
# dtype: int64

# %%
reviews=pd.read_csv('/content/supermarket_sales - Sheet1.csv')
reviews
# Out:
#       Invoice ID Branch  ... gross income Rating
# 0    750-67-8428      A  ...      26.1415    9.1
# 1    226-31-3081      C  ...       3.8200    9.6
# 2    631-41-3108      A  ...      16.2155    7.4
# 3    123-19-1176      A  ...      23.2880    8.4
# 4    373-73-7910      A  ...      30.2085    5.3
# ..           ...    ...  ...          ...    ...
# 995  233-67-5758      C  ...       2.0175    6.2
# 996  303-96-2227      B  ...      48.6900    4.4
# 997  727-02-1313      A  ...       1.5920    7.7
# 998  347-56-2442      A  ...       3.2910    4.1
# 999  849-09-3807      A  ...      30.9190    6.6
#
# [1000 rows x 17 columns]

# %%
import matplotlib.pyplot as plt
_ = plt.hist(reviews['Product line'])
_ = plt.xlabel('percent of vote for Obama')
_ = plt.ylabel('number of counties')
plt.show()

# %%
reviews.iloc[100]# hang 100
# Out:
# Invoice ID                         163-56-7055
# Branch                                       C
# City                                 Naypyitaw
# Customer type                           Member
# Gender                                    Male
# Product line               Fashion accessories
# Unit price                               48.71
# Quantity                                     1
# Tax 5%                                  2.4355
# Total                                  51.1455
# Date                                 3/26/2019
# Time                                     19:20
# Payment                                   Cash
# cogs                                     48.71
# gross margin percentage                 4.7619
# gross income                            2.4355
# Rating                                     4.1
# Name: 100, dtype: object

# %%
reviews.iloc[0:10,2] # tu 1 den 11 cua cot 3
# Out:
# 0       Yangon
# 1    Naypyitaw
# 2       Yangon
# 3       Yangon
# 4       Yangon
# 5    Naypyitaw
# 6       Yangon
# 7    Naypyitaw
# 8       Yangon
# 9     Mandalay
# Name: City, dtype: object

# %%
reviews.iloc[0:10,5] # tu 1 den 11 cua cot 6
# Out:
# 0         Health and beauty
# 1    Electronic accessories
# 2        Home and lifestyle
# 3         Health and beauty
# 4         Sports and travel
# 5    Electronic accessories
# 6    Electronic accessories
# 7        Home and lifestyle
# 8         Health and beauty
# 9        Food and beverages
# Name: Product line, dtype: object

# %%
reviews.iloc[[1,5,10],2]# lay du lieu hang 2,6, 11 cot 3
# Out:
# 1     Naypyitaw
# 5     Naypyitaw
# 10     Mandalay
# Name: City, dtype: object

# %%
reviews.iloc[-200:-100]# lay du lieu tu hang 800 den 900
# Out:
#       Invoice ID Branch  ... gross income Rating
# 800  751-15-6198      B  ...       6.9030    7.9
# 801  324-41-6833      C  ...      12.0800    5.1
# 802  474-33-8305      C  ...      23.5865    6.9
# 803  759-29-9521      A  ...      22.0320    8.0
# 804  831-81-6575      B  ...      34.0155    8.0
# ..           ...    ...  ...          ...    ...
# 895  699-88-1972      B  ...      39.6640    4.2
# 896  781-84-8059      C  ...      21.2590    5.0
# 897  409-49-6995      C  ...      14.1810    8.8
# 898  725-54-0677      C  ...      29.9600    5.3
# 899  146-09-5432      A  ...      15.7680    4.6
#
# [100 rows x 17 columns]

# %%
reviews.iloc[800:900]
# Out:
#       Invoice ID Branch  ... gross income Rating
# 800  751-15-6198      B  ...       6.9030    7.9
# 801  324-41-6833      C  ...      12.0800    5.1
# 802  474-33-8305      C  ...      23.5865    6.9
# 803  759-29-9521      A  ...      22.0320    8.0
# 804  831-81-6575      B  ...      34.0155    8.0
# ..           ...    ...  ...          ...    ...
# 895  699-88-1972      B  ...      39.6640    4.2
# 896  781-84-8059      C  ...      21.2590    5.0
# 897  409-49-6995      C  ...      14.1810    8.8
# 898  725-54-0677      C  ...      29.9600    5.3
# 899  146-09-5432      A  ...      15.7680    4.6
#
# [100 rows x 17 columns]

# %%
reviews.City=='Yangon'
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 995    False
# 996    False
# 997     True
# 998     True
# 999     True
# Name: City, Length: 1000, dtype: bool

# %%
reviews.loc[reviews.City=='Yangon'] #in ra bang du lieu ma City=Yangon
# Out:
#       Invoice ID Branch    City  ... gross margin percentage gross income Rating
# 0    750-67-8428      A  Yangon  ...                4.761905      26.1415    9.1
# 2    631-41-3108      A  Yangon  ...                4.761905      16.2155    7.4
# 3    123-19-1176      A  Yangon  ...                4.761905      23.2880    8.4
# 4    373-73-7910      A  Yangon  ...                4.761905      30.2085    5.3
# 6    355-53-5943      A  Yangon  ...                4.761905      20.6520    5.8
# ..           ...    ...     ...  ...                     ...          ...    ...
# 990  886-18-2897      A  Yangon  ...                4.761905      14.1400    4.5
# 992  745-74-0715      A  Yangon  ...                4.761905       5.8030    8.8
# 997  727-02-1313      A  Yangon  ...                4.761905       1.5920    7.7
# 998  347-56-2442      A  Yangon  ...                4.761905       3.2910    4.1
# 999  849-09-3807      A  Yangon  ...                4.761905      30.9190    6.6
#
# ...

# %%
reviews.loc[(reviews.City=='Yangon')&(reviews.Quantity>8)] #in ra bang du lieu ma City=Yangon va Quantity>8
# Out:
#       Invoice ID Branch    City  ... gross margin percentage gross income Rating
# 13   252-56-2699      A  Yangon  ...                4.761905      21.5950    8.2
# 14   829-34-3910      A  Yangon  ...                4.761905      35.6900    5.7
# 29   848-62-7243      A  Yangon  ...                4.761905      11.2005    7.4
# 37   272-65-1806      A  Yangon  ...                4.761905      27.3960    4.7
# 58   817-48-8732      A  Yangon  ...                4.761905      36.1750    5.4
# ..           ...    ...     ...  ...                     ...          ...    ...
# 932  243-55-8457      A  Yangon  ...                4.761905      37.2200    5.1
# 942  809-69-9497      A  Yangon  ...                4.761905      22.8400    5.7
# 959  384-59-6655      A  Yangon  ...                4.761905      44.3970    8.4
# 966  558-60-5016      A  Yangon  ...                4.761905      14.9850    7.2
# 982  139-32-4183      A  Yangon  ...                4.761905      43.8660    7.4
#
# ...

# %%
reviews.loc[(reviews.City=='Yangon')|(reviews.Quantity>8)] #in ra bang du lieu ma City=Yangon hoac Quantity>8
# Out:
#       Invoice ID Branch  ... gross income Rating
# 0    750-67-8428      A  ...      26.1415    9.1
# 2    631-41-3108      A  ...      16.2155    7.4
# 3    123-19-1176      A  ...      23.2880    8.4
# 4    373-73-7910      A  ...      30.2085    5.3
# 6    355-53-5943      A  ...      20.6520    5.8
# ..           ...    ...  ...          ...    ...
# 993  690-01-6631      B  ...       8.7450    6.6
# 996  303-96-2227      B  ...      48.6900    4.4
# 997  727-02-1313      A  ...       1.5920    7.7
# 998  347-56-2442      A  ...       3.2910    4.1
# 999  849-09-3807      A  ...      30.9190    6.6
#
# [482 rows x 17 columns]

# %%
reviews.loc[reviews.City.isin(['Yangon','Mandalay'])] #in ra bang du lieu ma City=Yangon hoac Madalay
# Out:
#       Invoice ID Branch  ... gross income Rating
# 0    750-67-8428      A  ...      26.1415    9.1
# 2    631-41-3108      A  ...      16.2155    7.4
# 3    123-19-1176      A  ...      23.2880    8.4
# 4    373-73-7910      A  ...      30.2085    5.3
# 6    355-53-5943      A  ...      20.6520    5.8
# ..           ...    ...  ...          ...    ...
# 993  690-01-6631      B  ...       8.7450    6.6
# 996  303-96-2227      B  ...      48.6900    4.4
# 997  727-02-1313      A  ...       1.5920    7.7
# 998  347-56-2442      A  ...       3.2910    4.1
# 999  849-09-3807      A  ...      30.9190    6.6
#
# [672 rows x 17 columns]

# %%
reviews.loc[reviews.Total.notnull()] # in ra bang du lieu ma cot total not null
# Out:
#       Invoice ID Branch  ... gross income Rating
# 0    750-67-8428      A  ...      26.1415    9.1
# 1    226-31-3081      C  ...       3.8200    9.6
# 2    631-41-3108      A  ...      16.2155    7.4
# 3    123-19-1176      A  ...      23.2880    8.4
# 4    373-73-7910      A  ...      30.2085    5.3
# ..           ...    ...  ...          ...    ...
# 995  233-67-5758      C  ...       2.0175    6.2
# 996  303-96-2227      B  ...      48.6900    4.4
# 997  727-02-1313      A  ...       1.5920    7.7
# 998  347-56-2442      A  ...       3.2910    4.1
# 999  849-09-3807      A  ...      30.9190    6.6
#
# [1000 rows x 17 columns]

# %%
reviews.City.describe() # mo ta ve cot City
# Out:
# count       1000
# unique         3
# top       Yangon
# freq         340
# Name: City, dtype: object

# %%
reviews.describe() # thong ke mo ta cho cac truong
# Out:
#         Unit price     Quantity  ...  gross income      Rating
# count  1000.000000  1000.000000  ...   1000.000000  1000.00000
# mean     55.672130     5.510000  ...     15.379369     6.97270
# std      26.494628     2.923431  ...     11.708825     1.71858
# min      10.080000     1.000000  ...      0.508500     4.00000
# 25%      32.875000     3.000000  ...      5.924875     5.50000
# 50%      55.230000     5.000000  ...     12.088000     7.00000
# 75%      77.935000     8.000000  ...     22.445250     8.50000
# max      99.960000    10.000000  ...     49.650000    10.00000
#
# [8 rows x 8 columns]

# %%
import numpy as np

np.cov(	reviews['Unit price'],reviews['Quantity']	)
# Out:
# array([[701.96533129,   0.83477848],
#        [  0.83477848,   8.54644645]])

# %%
np.corrcoef(	reviews['Unit price'],reviews['Quantity']	)
# Out:
# array([[1.        , 0.01077756],
#        [0.01077756, 1.        ]])

# %%
reviews.City.unique() #Liet ke cac doi tuong trong truong City
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
reviews.Quantity.unique() #Liet ke cac doi tuong phan biet trong truong Quantity
# Out:
# array([ 7,  5,  8,  6, 10,  2,  3,  4,  1,  9])

# %%
reviews.City.value_counts() #Tan so xuat hien cac thanh pho trong du lieu
# Out:
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: City, dtype: int64

# %%
reviews.Total.value_counts() #Tan so xuat hien cac thanh pho trong du lieu
# Out:
# 175.9170    2
# 829.0800    2
# 189.0945    2
# 470.9880    2
# 93.7440     2
#            ..
# 78.4350     1
# 742.2975    1
# 55.2825     1
# 250.2780    1
# 26.2500     1
# Name: Total, Length: 990, dtype: int64

# %%
quantity_mean=reviews.Quantity.mean()
print('mean',quantity_mean)
reviews.Quantity.map(lambda p:(p-quantity_mean)**2) # thay gia tri ban dau p bang gia tri moi (p-mean)^2
# Out:
# mean 5.51
# 0       2.2201
# 1       0.2601
# 2       2.2201
# 3       6.2001
# 4       2.2201
#         ...
# 995    20.3401
# 996    20.1601
# 997    20.3401
# 998    20.3401
# 999     2.2201
# Name: Quantity, Length: 1000, dtype: float64

# %%
Total_mean=reviews.Total.mean()
print('mean',Total_mean)
reviews.Quantity.map(lambda a:(a-Total_mean)**2) # thay gia tri ban dau p bang gia tri moi (p-mean)^2
# Out:
# mean 322.96674900000005
# 0       99834.986474
# 1      101102.853470
# 2       99834.986474
# 3       99204.052976
# 4       99834.986474
#            ...
# 995    103662.587462
# 996     97948.185980
# 997    103662.587462
# 998    103662.587462
# 999     99834.986474
# Name: Quantity, Length: 1000, dtype: float64

# %%
reviews.Branch+'*'+reviews.City # Tao ra mot cot moi
# Out:
# 0         A*Yangon
# 1      C*Naypyitaw
# 2         A*Yangon
# 3         A*Yangon
# 4         A*Yangon
#           ...
# 995    C*Naypyitaw
# 996     B*Mandalay
# 997       A*Yangon
# 998       A*Yangon
# 999       A*Yangon
# Length: 1000, dtype: object
