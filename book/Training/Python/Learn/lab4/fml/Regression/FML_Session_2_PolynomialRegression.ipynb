# %% [markdown]
# # Import module

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Simple Polynomial Regression

# %%
import numpy
import matplotlib.pyplot as plt

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

poly_model = numpy.poly1d(numpy.polyfit(x, y, 3))

myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, poly_model(myline), c='red')
plt.xlabel('Independent variable')
plt.ylabel('Dependent variable')
plt.show()

# %%
import numpy
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))
# Out:
# 0.9432150416451025

# %% [markdown]
# ## Bad Fit

# %%
import numpy
import matplotlib.pyplot as plt

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

bad_model = numpy.poly1d(numpy.polyfit(x, y, 3))

myline = numpy.linspace(2, 95, 100)

plt.scatter(x, y)
plt.plot(myline, bad_model(myline), c='red')
plt.xlabel('Independent variable')
plt.ylabel('Dependent variable')
plt.show()

# %% [markdown]
# ## R2 Score

# %%
import numpy
from sklearn.metrics import r2_score

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

bad_model = numpy.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, bad_model(x)))
# Out:
# 0.009952707566680652

# %% [markdown]
# # Polynomial Regression with sklearn

# %% [markdown]
# ## Polynomial Features

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
X = np.arange(6).reshape(3, 2)
print(X)
poly = PolynomialFeatures(degree=2)
poly.fit_transform(X)
# Out:
# [[0 1]
#  [2 3]
#  [4 5]]
# array([[ 1.,  0.,  1.,  0.,  0.,  1.],
#        [ 1.,  2.,  3.,  4.,  6.,  9.],
#        [ 1.,  4.,  5., 16., 20., 25.]])

# %% [markdown]
# ## Dataset

# %%
# importing libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# for calculating mean_squared error
from sklearn.metrics import mean_squared_error

# creating a dataset with curvilinear relationship
x=10*np.random.normal(0,1,70)
y=10*(-x**2)+np.random.normal(-100,100,70)

# plotting dataset
plt.figure(figsize=(10,5))
plt.scatter(x,y,s=15)
plt.xlabel('Predictor',fontsize=16)
plt.ylabel('Target',fontsize=16)
plt.show()

# %%
# importing libraries for polynomial transform
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

poly_features = PolynomialFeatures(degree=2)
linear_model = LinearRegression()

x_transform = poly_features.fit_transform(x.reshape(-1, 1))
linear_model.fit(x_transform, y.reshape(-1,1))

# %%
x_transform = poly_features.fit_transform(x.reshape(-1, 1))
poly_pred=linear_model.predict(x_transform)
#sorting predicted values with respect to predictor
sorted_zip = sorted(zip(x,poly_pred))
x_poly, poly_pred = zip(*sorted_zip)
#plotting predictions
plt.figure(figsize=(10,6))
plt.scatter(x,y,s=15)
plt.plot(x_poly,poly_pred,color='g',label='Polynomial Regression')
plt.xlabel('Predictor',fontsize=16)
plt.ylabel('Target',fontsize=16)
plt.legend()
plt.show()

# %%
print('R2 Score for Polynomial Regression=>', r2_score(y,poly_pred))
# Out:
# R2 Score for Polynomial Regression=> -0.37198591980028106

# %%
print(len(linear_model.coef_[0]))
linear_model.coef_
# Out:
# 3
# array([[ 0.        ,  0.58702771, -9.96148474]])

# %%
linear_model.intercept_
# Out:
# array([-97.52588926])
