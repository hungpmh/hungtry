# %% [markdown]
# # Exceptions
# ## Exceptions versus Syntax Errors

# %%
print( 0 / 0 )
# Out:
#   File "<ipython-input-1-c3931f671051>", line 1
#     print( 0 / 0 ))
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Raising an Exception

# %%
x = 10
if x > 5:
    raise Exception('x should not exceed 5. The value of x was: {}'.format(x))

# %% [markdown]
# ## The AssertionError Exception

# %%
import sys
assert ('linux' in sys.platform), "This code runs on Linux only."

# %% [markdown]
# ## The try and except Block: Handling Exceptions

# %%
def linux_interaction(os_name):
    assert (os_name in sys.platform), "Function can only run on Linux systems."
    print('Doing something.')

# %%
try:
    linux_interaction('windows')
except:
    print('Linux function was not executed')
# Out:
# Linux function was not executed

# %%
try:
    linux_interaction('windows')
except AssertionError as error:
    print(error)
    print('The linux_interaction() function was not executed')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-f76ad3d0d158> in <module>
#       1 try:
# ----> 2     linux_interaction('windows')
#       3 except AssertionError as error:
#       4     print(error)
#       5     print('The linux_interaction() function was not executed')
#
# NameError: name 'linux_interaction' is not defined

# %% [markdown]
# > FileNotFoundError

# %%
try:
    with open('file.log') as file:
        read_data = file.read()
except FileNotFoundError as fnf_error:
    print(fnf_error)
# Out:
# [Errno 2] No such file or directory: 'file.log'

# %%
try:
    linux_interaction('Windows')
    with open('file.log') as file:
        read_data = file.read()
except FileNotFoundError as fnf_error:
    print(fnf_error)
except AssertionError as error:
    print(error)
    print('Linux linux_interaction() function was not executed')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-66dc0a2066b3> in <module>
#       1 try:
# ----> 2     linux_interaction('Windows')
#       3     with open('file.log') as file:
#       4         read_data = file.read()
#       5 except FileNotFoundError as fnf_error:
#
# NameError: name 'linux_interaction' is not defined

# %% [markdown]
# ## The else Clause

# %%
try:
    linux_interaction('windows')
except AssertionError as error:
    print(error)
else:
    print('Executing the else clause.')
# Out:
# Function can only run on Linux systems.

# %% [markdown]
# ## Cleaning Up After Using finally

# %%
try:
    linux_interaction('windows')
except AssertionError as error:
    print(error)
else:
    try:
        with open('file.log') as file:
            read_data = file.read()
    except FileNotFoundError as fnf_error:
        print(fnf_error)
finally:
    print('Cleaning up, irrespective of any exceptions.')
# Out:
# Function can only run on Linux systems.
# Cleaning up, irrespective of any exceptions.
